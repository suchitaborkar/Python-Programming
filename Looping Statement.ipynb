# %% [markdown]
# ## if Statement

# %%
a = 39
b = 20
if b > a:
    print("a is greater")
    print("a")
    print("a is Maximum")
print("This statement is out of if block")
# Out:
# This statement is out of if block

# %%
num = -10
if num > 0:
    print(num, "is a positive number.")
    print(num)
    print("Positive")
else:
    print(num, "is a negative number.")
# Out:
# -10 is a negative number.

# %%
#User validation code
username=input("Enter username ")
password=input("Enter password ")

if username=="admin" and password=="ad123":
    print("You have entered correct credentials. Login is successful ")
else:
    print("You have entered incorrect credentials. Login is failed ")
# Out:
# Enter username Suchita
# Enter password 123
# You have entered incorrect credentials. Login is failed

# %% [markdown]
# ## for Loop

# %%
num = 0
if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Zero

# %%
digits = [0, 1, 5,6,7,8,7,5,4,3,22,2,2,22,2,22,2,22]
for i in digits:
    print(i)

# %%
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
mul=1
# variable to store the sum
# iterate over the list
for var1 in numbers:
    mul = mul * var1
    print(mul)
# Out:
# 6
# 30
# 90
# 720
# 2880
# 5760
# 28800
# 115200
# 1267200

# %%
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
sum=0
# variable to store the sum
# iterate over the list
for var1 in numbers:
    sum = sum + var1
    print("The sum is", sum)
average=sum/9
print(average)
# Out:
# The sum is 6
# The sum is 11
# The sum is 14
# The sum is 22
# The sum is 26
# The sum is 28
# The sum is 33
# The sum is 37
# The sum is 48
# 5.333333333333333

# %%
num=2
for i in range(1, 11):
    print(num, 'x', i, '=', num*i)
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %% [markdown]
# ## While Loop

# %%
print("Welcome!!!")
# Out:
# Welcome!!!

# %%
print("Welcome!!!")
print("Welcome!!!")
print("Welcome!!!")
print("Welcome!!!")
print("Welcome!!!")

# %%
#print no from 10 to 20
i=10
while i<=20:
    print(i)
    i=i+1

# %%
#print no from 1 to 10
print(1**2)
print(2**2)
print(3**2)
print(4**2)
print(5**2)
print(6**2)
print(7**2)
print(8**2)
print(9**2)
print(10**2)

# %%
#print square values of 1st 10 numbers
i=1
while i<=10:
    sq=i**2
    print(sq)
    i=i+1

# %%
#TASK - Guess the output
i=1
while i<=100:
    if i%2==0:
        print(i)
    i+=1

# %%
#TASK - Write Python code to print your name for 5 times

#loop counter initialization


#while loop condition
while :
    #print statement to print your name

    #increament value of loop counter by 1


print("End of code")

# %%
#TASK - Guess the output

i=10
while i<=20:
    print("Welcome!!!")
    i=i+1
print("End of code")

# %%
#loop counter initialization
i=1

#while loop condition
while i<=5:
    print("Welcome!!!")
    #increament value of loop counter by 1
    i=i+1

print("End of code")

# %%
number = int(input("Enter the number of which the user wants to print the multiplication table: "))
count = 1
# we are using while loop for iterating the multiplication 10 times

print ("The Multiplication Table of: ", number)
while count <= 10:
    number = number * 1
    print (number, 'x',count, '=', number * count)
#count=count+1
    count += 1
# Out:
# Enter the number of which the user wants to print the multiplication table: 5
# The Multiplication Table of:  5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
for val in "Data Science":
    if val == "i":
        break
    print(val)
print("The end")
# Out:
# D
# a
# t
# a
#
# S
# c
# The end

# %%
for val in "Data Science":
    if val == "c":
        continue
    print(val)
print("The end")
# Out:
# D
# a
# t
# a
#
# S
# i
# e
# n
# e
# The end

# %%
test_dict = {"Select Regenesys" : 1, "for" : 2, "Higher Studies" : 3}
# Printing dictionary
print ("Original dictionary is : " + str(test_dict))
# using in operator to
# get key and value
print ("Dict key-value are : ")
for i in test_dict :
    print(i, test_dict[i])
# Out:
# Original dictionary is : {'Select Regenesys': 1, 'for': 2, 'Higher Studies': 3}
# Dict key-value are :
# Select Regenesys 1
# for 2
# Higher Studies 3

# %%
#How to iterate over sequential data - STRING, LIST , TUPLE
lst=[2,1,5,8,5,6,18,13,11,15]

# %%
# print(lst[0])
# print(lst[1])
# print(lst[2])
# .
# .
# print(lst[9])

# %%
# while and list
lst=[2,1,5,8,5,6,18,13,11,15]
i=0
while i<len(lst):
    print(lst[i])
    i=i+1
# Out:
# 2
# 1
# 5
# 8
# 5
# 6
# 18
# 13
# 11
# 15
