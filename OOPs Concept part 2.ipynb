# %% [markdown]
# ## Object Oriented Programming

# %% [markdown]
# ## Inheritance

# %%
# Single Inheritance
class Parent:
    def displayA(self):
        print("I am in a Parent Class")
class Child(Parent):
    def displayB(self):
        print("I am in Child Class")
obj=Child()  # Object of a Child
obj1=Parent()

obj1.displayB() # using oject of parent you can call methods of child
obj1.displayA()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#       8 obj=Child()  # Object of a Child
#       9 obj1=Parent()
# ---> 11 obj1.displayB()
#      12 obj1.displayA()
#
# AttributeError: 'Parent' object has no attribute 'displayB'

# %%
# Multi Level Inheritance

class Parent:
    def displayParent(self):
        print(" I am in Parent Class")
class Child(Parent):
    def displayChild(self):
        print(" I am in Child Class")
class Grandchild(Child):
    def displayGrandchild(self):
        print(" I am in Grand child class")
obj=Grandchild()
obj.displayGrandchild()
obj.displayChild()
obj.displayParent()
# Out:
#  I am in Grand child class
#  I am in Child Class
#  I am in Parent Class

# %%
class A:
    def displayA(self):
        print("A")
class B(A):
    def displayB(self):
        print("B")
class C(B):
    def displayC(self):
        print("C")
class D(C):
    def displayD(self):
        print("D")
    
obj=D()
obj.displayA()
obj.displayB()
obj.displayC()
obj.displayD()
# Out:
# A
# B
# C
# D

# %%
# Multiple Inheritance

class Base1:
    def displayBase1(self):
        print("Base1")
class Base2:
    def displayBase2(self):
        print("Base2")
class Base3:
    def displayBase3(self):
        print("Base3")
class Derive(Base1,Base2,Base3):
    def displayderive(self):
        print("Derived")
obj=Derive()
obj.displayderive()
obj.displayBase1()
obj.displayBase2()
obj.displayBase3()
# Out:
# Derived
# Base1
# Base2
# Base3

# %%
class Base:
    def displayBase(self):
        print("Base Class")
class Child1(Base):
    def displaychild1(self):
        print("Child 1")
class Child2(Base):
    def displaychild2(self):
        print("Child 2")
obj=Child1()
obj.displaychild1()
obj1=Child2()
obj1.displaychild2()
obj.displayBase()
# Out:
# Child 1
# Child 2
# Base Class

# %%
# Task create Person class and address class( Base classes) 
#and create employee class which has Person and address as a base classes
# Whenever you need to call init of base class in child class use
# classname.__init(self,)
class Person:
    def __init__(self):
        print("I am a Person")
class Address:
    def __init__(self):
        print("This is the address")
class Person_Address(Person, Address):
    def __init__(self):
        print("This is Person Address")
        Person.__init__(self)  # super()
        Address.__init__(self)
obj = Person_Address()

#init method is initiated when the object is created
# Out:
# This is Person Address
# I am a Person
# This is the address

# %%
# Method Overiding( same method/function name in base as well child)
class A:
    def display(self):
        print("I am in A class")
class B(A):
    def display(self):
        print("I am in B class")
class C(B):
    def display(self):
        print("I am in C")
obj=C()
obj1=B()
obj1.display()
obj.display()
# Out:
# I am in B class
# I am in C

# %%
# super().__init__() helps to initiate init method of base class
class A:
    def __init__(self):
        print(" I am in A")
class C:
    def __init__(self):
        print("I am in C")
class B(A,C):
    def __init__(self):
        super().__init__() # Super()
        print("I am in B")
        C.__init__(self)
obj=B()
# Out:
#  I am in A
# I am in B
# I am in C

# %%
# Single Inheritance

class Person:
    def __init__(self, name):
        self.name = name

class Professor(Person):
    def isProfessor(self):
        return self.name

sir = Professor("John")
sir.isProfessor()
# Out:
# 'John'

# %%
# Single Inheritance
class Parent:
    def display_parent(self):
        print("Parent Class")
class Child(Parent):
    def display_child(self):
        print("Child Class")
obj=Child()
obj.display_parent()
obj.display_child()
# Out:
# Parent Class
# Child Class

# %%
#Multi-Level inheritance
class Parent:
    str1 = "Python"
class Child(Parent):
    str2 = "Geeks"
class GrandChild(Child):
    def get_str(self):
        print(self.str1 + self.str2)
person = GrandChild()
person.get_str()
# Out:
# PythonGeeks

# %%
#Multi-Level inheritance

class Animal:
    def __init__(self, species):
        self.species = species

    def make_sound(self):
        print("Some generic animal sound")

# Intermediate class inheriting from Animal
class Mammal(Animal):
    def give_birth(self):
        print("Giving birth to live young")

# Derived class inheriting from Mammal
class Dog(Mammal):
    def __init__(self, name):
        super().__init__("Canine")
        self.name = name

    def make_sound(self):
        print("Woof! Woof!")

# Creating an instance of Dog
my_dog = Dog("Buddy")

# Accessing methods from the base class
my_dog.make_sound()  # Outputs: Woof! Woof!
my_dog.give_birth()  # Outputs: Giving birth to live young

# Accessing attributes from the base class
print(my_dog.species)  # Outputs: Canine
print(my_dog.name)     # Outputs: Buddy
# Out:
# Woof! Woof!
# Giving birth to live young
# Canine
# Buddy

# %%
#Multiple Inheritance
class A:
    def method_A(self):
        print("Method from class A")

class B:
    def method_B(self):
        print("Method from class B")

class C(A, B):
    def method_C(self):
        print("Method from class C")

# Creating an instance of class C
obj_c = C()

# Accessing methods from all classes
obj_c.method_A()  # Outputs: Method from class A
obj_c.method_B()  # Outputs: Method from class B
obj_c.method_C()  # Outputs: Method from class C
# Out:
# Method from class A
# Method from class B
# Method from class C

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}")

class Address:
    def __init__(self, street, city, zip_code):
        self.street = street
        self.city = city
        self.zip_code = zip_code

    def display_address(self):
        print(f"Address: {self.street}, {self.city}, {self.zip_code}")

# Employee class inheriting from both Person and Address
class Employee(Person, Address):
    def __init__(self, name, age, employee_id, street, city, zip_code):
        # Initialize base class constructors explicitly
        Person.__init__(self, name, age)
        Address.__init__(self, street, city, zip_code)

        # Additional attribute for Employee class
        self.employee_id = employee_id

    def display_employee_info(self):
        print(f"Employee ID: {self.employee_id}")
        self.display_info()  # Call method from Person class
        self.display_address()  # Call method from Address class

# Creating an instance of Employee
employee = Employee("John Doe", 30, "E12345", "123 Main St", "Cityville", "12345")

# Accessing methods and attributes
employee.display_employee_info()
# Out:
# Employee ID: E12345
# Name: John Doe, Age: 30
# Address: 123 Main St, Cityville, 12345

# %%
# Create a Person class and employee child class

# %%
class Person():
  # __init__ is known as the constructor
    def __init__(self, name, idnumber):
        self.name = name
        self.idnumber = idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)

class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        self.salary = salary
        self.post = post

        # invoking the __init__ of the parent class
        Person.__init__(self, name, idnumber)

 # creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using its instance
a.display()
# Out:
# Rahul
# 886012

# %% [markdown]
# ## Method Overiding

# %%
#  Method Overiding
class Animal:
    def speak(self):
        print("speaking")
class Dog(Animal):
    def speak(self):
        print("Barking")
d = Dog()
d.speak()
# Out:
# Barking

# %%
class Bank:
    def getroi(self):
        return 10
class SBI(Bank):
    def getroi(self):
        return 7
class ICICI(Bank):
    def getroi(self):
        return 8
b1 = Bank()
b2 = SBI()
b3 = ICICI()
print("Bank Rate of interest:",b1.getroi())
print("SBI Rate of interest:",b2.getroi())
print("ICICI Rate of interest:",b3.getroi())
# Out:
# Bank Rate of interest: 10
# SBI Rate of interest: 7
# ICICI Rate of interest: 8

# %%
# Use of super () : allows us to run the init() method of the parent class
#inside the child class.
class Bird:
    def __init__(self):
        print("Bird is ready")
    def whoisThis(self):
        print("Bird")
    def swim(self):
        print("Swim faster") # child class

class Penguin(Bird):
    def __init__(self): # call super() function
        super().__init__()
        print("Penguin is ready")
    def whoisThis(self):
        print("Penguin")
    def run(self):
        print("Run faster")
peggy = Penguin()
peggy.whoisThis()
peggy.swim()
peggy.run()
# Out:
# Bird is ready
# Penguin is ready
# Penguin
# Swim faster
# Run faster

# %%
"""**EXPLAINATION**
We created two classes i.e. Bird (parent class) and Penguin (child class).
The child class inherits the functions of parent class.
We can see this from the swim() method.
Again, the child class modified the behavior of the parent class.
We can see this from the whoisThis() method.
Furthermore, we extend the functions of the parent class,
by creating a new run() method.
Additionally, we use the super() function inside the __init__() method.
This allows us to run the __init__() method of the parent class inside the child
class."""
# Out:
# '**EXPLAINATION**\nWe created two classes i.e. Bird (parent class) and Penguin (child class). \nThe child class inherits the functions of parent class. \nWe can see this from the swim() method. \nAgain, the child class modified the behavior of the parent class.\nWe can see this from the whoisThis() method. \nFurthermore, we extend the functions of the parent class, \nby creating a new run() method. \nAdditionally, we use the super() function inside the __init__() method. \nThis allows us to run the __init__() method of the parent class inside the child\nclass.'

# %%
#Python pass Statement

# %%
"""The pass statement is used as a placeholder for future code. When the pass statement is executed, nothing happens, but you avoid getting an error when empty code is not allowed. Empty code is not allowed in loops, function definitions, class definitions, or in if statements. """
# Out:
# 'The pass statement is used as a placeholder for future code. When the pass statement is executed, nothing happens, but you avoid getting an error when empty code is not allowed. Empty code is not allowed in loops, function definitions, class definitions, or in if statements. '

# %%
# pass statement

class Parent:
    def display(self):
        pass
class Child(Parent):
    def display_child(self):
        print("hello")
obj=Child()
obj.display_child()
# Out:
# hello

# %%
from abc import ABC, abstractmethod
class Car(ABC):
    def mileage(self):
        pass
class Tesla(Car):
    def mileage(self):
        print("The mileage is 30kmph")
class Suzuki(Car):
    def mileage(self):
        print("The mileage is 25kmph ")
class Duster(Car):
    def mileage(self):
        print("The mileage is 24kmph ")
class Renault(Car):
    def mileage(self):
        print("The mileage is 27kmph ")
# Driver code
t= Tesla ()
t.mileage()
r = Renault()
r.mileage()
s = Suzuki()
s.mileage()
d = Duster()
d.mileage()
# Out:
# The mileage is 30kmph
# The mileage is 27kmph
# The mileage is 25kmph
# The mileage is 24kmph

# %%
from abc import ABC, abstractmethod

class Polygon(ABC):
    def noofsides(self):
        pass
class Triangle(Polygon):

    # overriding abstract method
    def noofsides(self):
        print("I have 3 sides")


class Pentagon(Polygon):

    # overriding abstract method
    def noofsides(self):
        print("I have 5 sides")


class Hexagon(Polygon):

    # overriding abstract method
    def noofsides(self):
        print("I have 6 sides")


class Quadrilateral(Polygon):

    # overriding abstract method
    def noofsides(self):
        print("I have 4 sides")


# Driver code
R = Triangle()
R.noofsides()

K = Quadrilateral()
K.noofsides()

R = Pentagon()
R.noofsides()

K = Hexagon()
K.noofsides()
# Out:
# I have 3 sides
# I have 4 sides
# I have 5 sides
# I have 6 sides

# %%
"""**Explanation** - In the above code, we have imported the abc module to create the abstract base class. We created the Car class that inherited the ABC class and defined an abstract method named mileage(). We have then inherited the base class from the three different subclasses and implemented the abstract method differently. We created the objects to call the abstract method. """
# Out:
# '**Explanation** - In the above code, we have imported the abc module to create the abstract base class. We created the Car class that inherited the ABC class and defined an abstract method named mileage(). We have then inherited the base class from the three different subclasses and implemented the abstract method differently. We created the objects to call the abstract method. '

# %% [markdown]
# ## Polymorphism

# %%
#We know that the + operator is used extensively in Python programs.
#But, it does not have a single usage.
#For integer data types, + operator is used to perform arithmetic
#addition operation.

# %%
num1 = 1
num2 = 2
print(num1+num2)
str1 = "Python"
str2 = "Programming"
print(str1+" "+str2)

# %%
"""we can see that a single operator + has been used to carry out different
operations for distinct data types. This is one of the most simple occurrences
of polymorphism in Python."""
# Out:
# 'we can see that a single operator + has been used to carry out different \noperations for distinct data types. This is one of the most simple occurrences \nof polymorphism in Python.'

# %%
print(len("Programing"))
print(len(["Python", "Java", "C"]))
print(len({"Name": "John", "Address": "Nepal"}))
# Out:
# 10
# 3
# 2

# %%
#  Polymorphism demonstration

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def info(self):
        print(f"I am a cat. My name is {self.name}. I am {self.age} years old.")
    def make_sound(self):
        print("Meow")
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def info(self):
        print(f"I am a dog. My name is {self.name}. I am {self.age} years old.")
    def make_sound(self):
        print("Bark")
cat1 = Cat("Kitty", 2.5)
dog1 = Dog("Fluffy", 4)
for animal in (cat1, dog1):
    animal.make_sound()
    animal.info()
# Out:
# Meow
# I am a cat. My name is Kitty. I am 2.5 years old.
# Bark
# I am a dog. My name is Fluffy. I am 4 years old.

# %%
#  Polymorphism example for calculating area for different shapes
from math import pi
class Shape:
    def __init__(self, name):
        self.name = name
    def area(self):
        pass
    def fact(self):
        return "I am a two-dimensional shape."
    def __str__(self):
        return self.name
class Square(Shape):
    def __init__(self, length):
        super().__init__("Square")
        self.length = length
    def area(self):
        return self.length**2
    def fact(self):
        return "Squares have each angle equal to 90 degrees."
class Circle(Shape):
    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius
    def area(self):
        return pi*self.radius**2
a = Square(4)
b = Circle(7)
print(b)
print(b.fact())
print(a.fact())
print(b.area())
# Out:
# Circle
# I am a two-dimensional shape.
# Squares have each angle equal to 90 degrees.
# 153.93804002589985

# %%
"""Here, we can see that the methods such as __str__(),
which have not been overridden in the child classes, are used from the
parent class. Due to polymorphism, the Python interpreter automatically
recognizes that the fact() method for object a(Square class) is overridden.
So, it uses the one defined in the child class. On the other hand, since
the fact() method for object b isn't overridden,
it is used from the Parent Shape class. """
# Out:
# "Here, we can see that the methods such as __str__(), which have not been overridden in the child classes, are used from the parent class. Due to polymorphism, the Python interpreter automatically recognizes that the fact() method for object a(Square class) is overridden. So, it uses the one defined in the child class. On the other hand, since the fact() method for object b isn't overridden, it is used from the Parent Shape class. "

# %%
from abc import ABC, abstractmethod

# Define an abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Define concrete subclasses inheriting from Shape
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

# Instantiate objects of concrete subclasses
rectangle = Rectangle(5, 4)
circle = Circle(3)

# Call the area method on objects of concrete subclasses
print("Area of Rectangle:", rectangle.area())  # Output: 20
print("Area of Circle:", circle.area())        # Output: 28.26
# Out:
# Area of Rectangle: 20
# Area of Circle: 28.26

# %%
"""Abstraction is a fundamental concept in object-oriented programming that focuses on hiding the implementation details of a
 class and only showing the essential features of the object. In Python, you can achieve abstraction through abstract classes and methods using the abc module.
  An abstract class cannot be instantiated directly, and its methods must be implemented by its subclasses."""

# %%
"""In this example:

Shape is an abstract class with an abstract method area().
Rectangle and Circle are concrete subclasses of Shape where they implement the area() method according to their specific logic.
Attempting to instantiate Shape directly will raise an error because it's an abstract class.
Each concrete subclass provides its own implementation of the area() method, encapsulating the details of how the area is calculated for that particular shape.
Abstraction allows you to define a common interface for different subclasses while hiding their internal details. It promotes code reusability and makes the code easier to maintain and extend."""
